# %%
import pandas as pd

# %%
data =pd.read_csv('Cars Data.csv')

# %%
data.head()
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990   $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755   $39,014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
# 2         2.4        4.0       200.0      22.0         29.0  3230.0
# 3         3.2        6.0       270.0      20.0         28.0  3575.0
# 4         3.5        6.0       225.0      18.0         24.0  3880.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0
# 2      105.0   183.0
# 3      108.0   186.0
# 4      115.0   197.0

# %%
data.shape
# Out:
# (432, 15)

# %%
data.isnull().sum()
# Out:
# Make           4
# Model          4
# Type           4
# Origin         4
# DriveTrain     4
# MSRP           4
# Invoice        4
# EngineSize     4
# Cylinders      6
# Horsepower     4
# MPG_City       4
# MPG_Highway    4
# Weight         4
# Wheelbase      4
# Length         4
# dtype: int64

# %%
data.dropna(inplace = True)

# %%
data['Make'].value_counts()
# Out:
# Toyota           28
# Chevrolet        27
# Mercedes-Benz    26
# Ford             23
# BMW              20
# Audi             19
# Honda            17
# Nissan           17
# Volkswagen       15
# Chrysler         15
# Dodge            13
# Mitsubishi       13
# Hyundai          12
# Jaguar           12
# Volvo            12
# Subaru           11
# Pontiac          11
# Lexus            11
# Kia              11
# Lincoln           9
# Buick             9
# Mazda             9
# Mercury           9
# Saturn            8
# Cadillac          8
# Suzuki            8
# Infiniti          8
# GMC               8
# Acura             7
# Porsche           7
# Saab              7
# Land Rover        3
# Oldsmobile        3
# Jeep              3
# Scion             2
# Isuzu             2
# MINI              2
# Hummer            1
# Name: Make, dtype: int64

# %%
data[data['Origin'].isin(['Asia','Europe'])]
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 0    Acura                      MDX    SUV    Asia        All  $36,945
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# ..     ...                      ...    ...     ...        ...       ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
# 430  Volvo                      V40  Wagon  Europe      Front  $26,135
# 431  Volvo                     XC70  Wagon  Europe        All  $35,145
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
data[~(data['Weight']>4000)].count()
# Out:
# Make           323
# Model          323
# Type           323
# Origin         323
# DriveTrain     323
# MSRP           323
# Invoice        323
# EngineSize     323
# Cylinders      323
# Horsepower     323
# MPG_City       323
# MPG_Highway    323
# Weight         323
# Wheelbase      323
# Length         323
# dtype: int64

# %%
data.plot()
# Out:
# <AxesSubplot:>

# %%
data.plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
data.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
data.head()
# Out:
#     Make           Model   Type Origin DriveTrain      MSRP   Invoice  \
# 0  Acura             MDX    SUV   Asia        All  $36,945   $33,337
# 1  Acura  RSX Type S 2dr  Sedan   Asia      Front  $23,820   $21,761
# 2  Acura         TSX 4dr  Sedan   Asia      Front  $26,990   $24,647
# 3  Acura          TL 4dr  Sedan   Asia      Front  $33,195   $30,299
# 4  Acura      3.5 RL 4dr  Sedan   Asia      Front  $43,755   $39,014
#
#    EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  Weight  \
# 0         3.5        6.0       265.0      17.0         23.0  4451.0
# 1         2.0        4.0       200.0      24.0         31.0  2778.0
# 2         2.4        4.0       200.0      22.0         29.0  3230.0
# 3         3.2        6.0       270.0      20.0         28.0  3575.0
# 4         3.5        6.0       225.0      18.0         24.0  3880.0
#
#    Wheelbase  Length
# 0      106.0   189.0
# 1      101.0   172.0
# 2      105.0   183.0
# 3      108.0   186.0
# 4      115.0   197.0

# %%
data[['Make','Model','Type','Origin','EngineSize']]
# Out:
#       Make                    Model   Type  Origin  EngineSize
# 0    Acura                      MDX    SUV    Asia         3.5
# 1    Acura           RSX Type S 2dr  Sedan    Asia         2.0
# 2    Acura                  TSX 4dr  Sedan    Asia         2.4
# 3    Acura                   TL 4dr  Sedan    Asia         3.2
# 4    Acura               3.5 RL 4dr  Sedan    Asia         3.5
# ..     ...                      ...    ...     ...         ...
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe         2.4
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe         2.3
# 429  Volvo               S80 T6 4dr  Sedan  Europe         2.9
# 430  Volvo                      V40  Wagon  Europe         1.9
# 431  Volvo                     XC70  Wagon  Europe         2.5
#
# [426 rows x 5 columns]

# %%
data[data['Type'] == 'Sedan']
# Out:
#       Make                    Model   Type  Origin DriveTrain      MSRP  \
# 1    Acura           RSX Type S 2dr  Sedan    Asia      Front  $23,820
# 2    Acura                  TSX 4dr  Sedan    Asia      Front  $26,990
# 3    Acura                   TL 4dr  Sedan    Asia      Front  $33,195
# 4    Acura               3.5 RL 4dr  Sedan    Asia      Front  $43,755
# 5    Acura  3.5 RL w/Navigation 4dr  Sedan    Asia      Front  $46,100
# ..     ...                      ...    ...     ...        ...       ...
# 425  Volvo              S80 2.9 4dr  Sedan  Europe      Front  $37,730
# 426  Volvo             S80 2.5T 4dr  Sedan  Europe        All  $37,885
# 427  Volvo  C70 LPT convertible 2dr  Sedan  Europe      Front  $40,565
# 428  Volvo  C70 HPT convertible 2dr  Sedan  Europe      Front  $42,565
# 429  Volvo               S80 T6 4dr  Sedan  Europe      Front  $45,210
#
#       Invoice  EngineSize  Cylinders  Horsepower  MPG_City  MPG_Highway  \
# ...

# %%
data['Type'].value_counts().plot(kind ='bar')
# Out:
# <AxesSubplot:>

# %%
data.value_counts().to_frame()
# Out:
#                                                                                                                                                              0
# Make       Model                     Type  Origin DriveTrain MSRP     Invoice  EngineSize Cylinders Horsepower MPG_City MPG_Highway Weight Wheelbase Length
# Acura      3.5 RL 4dr                Sedan Asia   Front      $43,755  $39,014  3.5        6.0       225.0      18.0     24.0        3880.0 115.0     197.0   1
# Mitsubishi Lancer LS 4dr             Sedan Asia   Front      $16,722  $15,718  2.0        4.0       120.0      25.0     31.0        2795.0 102.0     181.0   1
#            Lancer ES 4dr             Sedan Asia   Front      $14,622  $13,751  2.0        4.0       120.0      25.0     31.0        2656.0 102.0     181.0   1
#            Galant GTS 4dr            Sedan Asia   Front      $25,700  $23,883  3.8        6.0       230.0      18.0     26.0        3649.0 108.0     191.0   1
# ...
